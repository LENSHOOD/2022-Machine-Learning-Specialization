# %%
# run first time
# import sys
# !{sys.executable} -m pip install "gymnasium[box2d]" imageio statsmodels pyvirtualdisplay tensorflow matplotlib numpy "imageio[ffmpeg]"

# %%
import time
from collections import deque, namedtuple

import gymnasium as gym
from gymnasium.envs.box2d.lunar_lander import LunarLander
import math
import numpy as np
import PIL.Image
import tensorflow as tf
import utils

# from pyvirtualdisplay import Display
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.losses import MSE
from tensorflow.keras.optimizers import Adam

# %%
class FancyLunarLander(LunarLander):
    def __init__(self, x_range, y_range, **kwargs):
        super().__init__(**kwargs)
        self.max_step_reward = 1.0
        self.max_angle_error = 1.0
        self.safe_x_range = x_range

        self.target_y = 1.0
        self.max_height_error = y_range

    def update_range(self, x_range, y_range):
        self.safe_x_range = x_range
        self.max_height_error = y_range
    
    def step(self, action):
        obs, reward, terminated, truncated, info = super().step(action)
        x, y = obs[:2]
        
        # horizontal
        if abs(x) <= self.safe_x_range:
            zone_reward = 0.2 * (1 - abs(x) / self.safe_x_range)
        else:
            zone_reward = -2.0 * (abs(x) - self.safe_x_range)

        # vertical
        height_err = abs(y - self.target_y)
        if height_err < self.max_height_error:
            height_reward = 0.5 * (1 - height_err / self.max_height_error)
        else:
            height_reward = -1.0 * (height_err - self.max_height_error)

        # composed rewards
        reward = zone_reward + height_reward

        return obs, reward, terminated, truncated, info

# %%
class ZeroLunarLander(LunarLander):
    def __init__(self, x_range, y_range, **kwargs):
        super().__init__(**kwargs)
        self.gravity = 0.0
        self.upside_down_steps = 0
        
        self.max_step_reward = 1.0
        self.max_angle_error = 1.0
        self.safe_x_range = x_range

        self.target_y = 1.0
        self.max_height_error = y_range

    def update_range(self, x_range, y_range):
        self.safe_x_range = x_range
        self.max_height_error = y_range
    
    def step(self, action):
        obs, reward, terminated, truncated, info = super().step(action)
        x, y, _, angle = obs[:4]
        
        upside_down = abs(abs(angle) - 6.283018) < 0.3

        if upside_down:
            self.upside_down_steps += 1
        else:
            self.upside_down_steps = 0
        
        # horizontal
        if abs(x) <= self.safe_x_range:
            zone_reward = 0.2 * (1 - abs(x) / self.safe_x_range)
        else:
            zone_reward = -2.0 * (abs(x) - self.safe_x_range)

        # vertical
        height_err = abs(y - self.target_y)
        if height_err < self.max_height_error:
            height_reward = 0.5 * (1 - height_err / self.max_height_error)
        else:
            height_reward = -1.0 * (height_err - self.max_height_error)

        # composed rewards
        reward = zone_reward + height_reward
        if upside_down:
            reward += 10
        else:
            reward -= 1

        return obs, reward, terminated, truncated, info

# %%
# Set the random seed for TensorFlow
tf.random.set_seed(utils.SEED)

# %%
MEMORY_SIZE = 100_000     # size of memory buffer
GAMMA = 0.995             # discount factor
ALPHA = 1e-4              # learning rate  
NUM_STEPS_FOR_UPDATE = 4  # perform a learning update every C time steps
MAX_TIME_LIMIT = 500      # max time limit
X_RANGE_INIT = 0.5
Y_RANGE_INIT = 0.3
X_RANGE_END = 0.01
Y_RANGE_END = 0.01

# %%
# env = gym.make('LunarLander-v3', render_mode='rgb_array')
env = gym.wrappers.TimeLimit(
    ZeroLunarLander(x_range=X_RANGE_INIT, y_range=Y_RANGE_INIT, render_mode='rgb_array'),
    max_episode_steps=MAX_TIME_LIMIT
)

# %%
env.reset()
PIL.Image.fromarray(env.render())
# Out:
# <PIL.Image.Image image mode=RGB size=600x400>

# %%
# UNQ_C1
# GRADED CELL

state_size = env.observation_space.shape
num_actions = env.action_space.n

# Create the Q-Network
q_network = Sequential([
    Input(shape=state_size),
    Dense(64, activation='relu'),
    Dense(64, activation='relu'),
    Dense(num_actions, activation='linear')
    ])

# Create the target Q^-Network
target_q_network = Sequential([
    Input(shape=state_size),
    Dense(64, activation='relu'),
    Dense(64, activation='relu'),
    Dense(num_actions, activation='linear')
    ])

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=ALPHA,
    decay_steps=10000,
    decay_rate=0.96,
    staircase=True
)
optimizer = Adam(learning_rate=lr_schedule)

# %%
# Store experiences as named tuples
experience = namedtuple("Experience", field_names=["state", "action", "reward", "next_state", "done"])

# %%
# UNQ_C2
# GRADED FUNCTION: calculate_loss

def compute_loss(experiences, gamma, q_network, target_q_network):
    """ 
    Calculates the loss.
    
    Args:
      experiences: (tuple) tuple of ["state", "action", "reward", "next_state", "done"] namedtuples
      gamma: (float) The discount factor.
      q_network: (tf.keras.Sequential) Keras model for predicting the q_values
      target_q_network: (tf.keras.Sequential) Karas model for predicting the targets
          
    Returns:
      loss: (TensorFlow Tensor(shape=(0,), dtype=int32)) the Mean-Squared Error between
            the y targets and the Q(s,a) values.
    """
    
    # Unpack the mini-batch of experience tuples
    states, actions, rewards, next_states, done_vals = experiences
    
    # Compute max Q^(s,a)
    max_qsa = tf.reduce_max(target_q_network(next_states), axis=-1)
    
    # Set y = R if episode terminates, otherwise set y = R + γ max Q^(s,a).
    y_targets = rewards + (1.0 - done_vals) * gamma * max_qsa
    
    # Get the q_values
    q_values = q_network(states)
    q_values = tf.gather_nd(q_values, tf.stack([tf.range(q_values.shape[0]),
                                                tf.cast(actions, tf.int32)], axis=1))
        
    # Compute the loss
    loss = MSE(y_targets, q_values)
    
    return loss

# %%
@tf.function
def agent_learn(experiences, gamma):
    """
    Updates the weights of the Q networks.
    
    Args:
      experiences: (tuple) tuple of ["state", "action", "reward", "next_state", "done"] namedtuples
      gamma: (float) The discount factor.
    
    """
    
    # Calculate the loss
    with tf.GradientTape() as tape:
        loss = compute_loss(experiences, gamma, q_network, target_q_network)

    # Get the gradients of the loss with respect to the weights.
    gradients = tape.gradient(loss, q_network.trainable_variables)
    
    # Update the weights of the q_network.
    optimizer.apply_gradients(zip(gradients, q_network.trainable_variables))

    # update the weights of target q_network
    utils.update_target_network(q_network, target_q_network)

# %%
start = time.time()

num_episodes = 4000
max_num_timesteps = 1000

total_point_history = []

num_p_av = 100    # number of total points to use for averaging
epsilon = 1.0     # initial ε value for ε-greedy policy

# Create a memory buffer D with capacity N
memory_buffer = deque(maxlen=MEMORY_SIZE)

# Set the target network weights equal to the Q-Network weights
target_q_network.set_weights(q_network.get_weights())

step = 5
range_step_x = (X_RANGE_INIT - X_RANGE_END) / step
range_step_y = (Y_RANGE_INIT - Y_RANGE_END) / step
for i in range(step+1):   
    curr_x_range = X_RANGE_INIT - range_step_x * i
    curr_y_range = Y_RANGE_INIT - range_step_y * i
    env.unwrapped.update_range(x_range = curr_x_range, y_range = curr_y_range) 
    total_point_history = []
    print(f"\rStep{i}, x range: {curr_x_range}, y range: {curr_y_range}")
    
    for i in range(num_episodes):
        
        # Reset the environment to the initial state and get the initial state
        state, _ = env.reset()
        total_points = 0
        
        for t in range(max_num_timesteps):
            
            # From the current state S choose an action A using an ε-greedy policy
            state_qn = np.expand_dims(state, axis=0)  # state needs to be the right shape for the q_network
            q_values = q_network(state_qn)
            action = utils.get_action(q_values, epsilon)
            
            # Take action A and receive reward R and the next state S'
            next_state, reward, done, _, _ = env.step(action)
            
            # Store experience tuple (S,A,R,S') in the memory buffer.
            # We store the done variable as well for convenience.
            memory_buffer.append(experience(state, action, reward, next_state, done))
            
            # Only update the network every NUM_STEPS_FOR_UPDATE time steps.
            update = utils.check_update_conditions(t, NUM_STEPS_FOR_UPDATE, memory_buffer)
            
            if update:
                # Sample random mini-batch of experience tuples (S,A,R,S') from D
                experiences = utils.get_experiences(memory_buffer)
                
                # Set the y targets, perform a gradient descent step,
                # and update the network weights.
                agent_learn(experiences, GAMMA)
            
            state = next_state.copy()
            total_points += reward
            
            if done:
                break
                
        total_point_history.append(total_points)
        av_latest_points = np.mean(total_point_history[-num_p_av:])
        
        # Update the ε value
        epsilon = utils.get_new_eps(epsilon)
    
        print(f"\rEpisode {i+1} | Total point average of the last {num_p_av} episodes: {av_latest_points:.2f}", end="")
    
        if (i+1) % num_p_av == 0:
            print(f"\rEpisode {i+1} | Total point average of the last {num_p_av} episodes: {av_latest_points:.2f}")
    
        # We will consider that the environment is solved if we get an
        # average of 200 points in the last 100 episodes.
        if av_latest_points >= 200.0:
            print(f"\n\nEnvironment solved in {i+1} episodes!")
            q_network.save('lunar_lander_model.h5')
            break
        
tot_time = time.time() - start

print(f"\nTotal Runtime: {tot_time:.2f} s ({(tot_time/60):.2f} min)")
# Out:
# Step0, x range: 0.5, y range: 0.3
# Episode 100 | Total point average of the last 100 episodes: -597.62
# Episode 200 | Total point average of the last 100 episodes: -480.13
# Episode 212 | Total point average of the last 100 episodes: -466.89
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 37
#      33 for t in range(max_num_timesteps):
#      34
#      35     # From the current state S choose an action A using an ε-greedy policy
#      36     state_qn = np.expand_dims(state, axis=0)  # state needs to be the right shape for the q_network
# ---> 37     q_values = q_network(state_qn)
#      38     action = utils.get_action(q_values, epsilon)
#      40     # Take action A and receive reward R and the next state S'
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/keras/src/layers/layer.py:941, in Layer.__call__(self, *args, **kwargs)
#     939         outputs = super().__call__(*args, **kwargs)
#     940 else:
# --> 941     outputs = super().__call__(*args, **kwargs)
#     942 # Change the layout for the layer output if needed.
#     943 # This is useful for relayout intermediate tensor in the model
#     944 # to achieve the optimal performance.
#     945 distribution = distribution_lib.distribution()
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/keras/src/ops/operation.py:59, in Operation.__call__(self, *args, **kwargs)
#      54                 call_fn = self.call
#      55     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      56         call_fn,
#      57         object_name=(f"{self.__class__.__name__}.call()"),
#      58     )
# ---> 59     return call_fn(*args, **kwargs)
#      61 # Plain flow.
#      62 if any_symbolic_tensors(args, kwargs):
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/keras/src/models/sequential.py:220, in Sequential.call(self, inputs, training, mask, **kwargs)
#     218 def call(self, inputs, training=None, mask=None, **kwargs):
#     219     if self._functional:
# --> 220         return self._functional.call(
#     221             inputs, training=training, mask=mask, **kwargs
#     222         )
#     224     # Fallback: Just apply the layer sequence.
#     225     # This typically happens if `inputs` is a nested struct.
#     226     for layer in self.layers:
#     227         # During each iteration, `inputs` are the inputs to `layer`, and
#     228         # `outputs` are the outputs of `layer` applied to `inputs`. At the
#     229         # end of each iteration `inputs` is set to `outputs` to prepare for
#     230         # the next layer.
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/keras/src/models/functional.py:183, in Functional.call(self, inputs, training, mask, **kwargs)
#     181         if mask is not None:
#     182             backend.set_keras_mask(x, mask)
# --> 183 outputs = self._run_through_graph(
#     184     inputs,
#     185     operation_fn=lambda op: operation_fn(
#     186         op, training=training, **kwargs
#     187     ),
#     188 )
#     189 return unpack_singleton(outputs)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/keras/src/ops/function.py:206, in Function._run_through_graph(self, inputs, operation_fn, call_fn)
#     204     operation = self._get_operation_for_node(node)
#     205     op = operation_fn(operation)
# --> 206     outputs = op(*args, **kwargs)
#     208 # Update tensor_dict.
#     209 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/keras/src/models/functional.py:644, in operation_fn.<locals>.call(*args, **kwargs)
#     638     if (
#     639         name in getattr(operation, "_call_context_args", {})
#     640         and value is not None
#     641     ):
#     642         kwargs[name] = value
# --> 644 return operation(*args, **kwargs)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/keras/src/layers/layer.py:941, in Layer.__call__(self, *args, **kwargs)
#     939         outputs = super().__call__(*args, **kwargs)
#     940 else:
# --> 941     outputs = super().__call__(*args, **kwargs)
#     942 # Change the layout for the layer output if needed.
#     943 # This is useful for relayout intermediate tensor in the model
#     944 # to achieve the optimal performance.
#     945 distribution = distribution_lib.distribution()
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/keras/src/ops/operation.py:59, in Operation.__call__(self, *args, **kwargs)
#      54                 call_fn = self.call
#      55     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      56         call_fn,
#      57         object_name=(f"{self.__class__.__name__}.call()"),
#      58     )
# ---> 59     return call_fn(*args, **kwargs)
#      61 # Plain flow.
#      62 if any_symbolic_tensors(args, kwargs):
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/keras/src/layers/core/dense.py:187, in Dense.call(self, inputs, training)
#     186 def call(self, inputs, training=None):
# --> 187     x = ops.matmul(inputs, self.kernel)
#     188     if self.bias is not None:
#     189         x = ops.add(x, self.bias)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/keras/src/ops/numpy.py:4607, in matmul(x1, x2)
#    4605 if any_symbolic_tensors((x1, x2)):
#    4606     return Matmul().symbolic_call(x1, x2)
# -> 4607 return backend.numpy.matmul(x1, x2)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/keras/src/backend/tensorflow/numpy.py:520, in matmul(x1, x2)
#     518     output_type = None
#     519 x1 = tf.cast(x1, compute_dtype)
# --> 520 x2 = tf.cast(x2, compute_dtype)
#     522 def with_combined_batch_dimensions(a, b, output_shape, fn_3d):
#     523     a_sparse = isinstance(a, tf.SparseTensor)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/tensorflow/python/util/dispatch.py:1264, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1262 # Fallback dispatch system (dispatch v1):
#    1263 try:
# -> 1264   return dispatch_target(*args, **kwargs)
#    1265 except (TypeError, ValueError):
#    1266   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1267   # TypeError, when given unexpected types.  So we need to catch both.
#    1268   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/tensorflow/python/ops/math_ops.py:1012, in cast(x, dtype, name)
#    1006   x = indexed_slices.IndexedSlices(values_cast, x.indices, x.dense_shape)
#    1007 else:
#    1008   # TODO(josh11b): If x is not already a Tensor, we could return
#    1009   # ops.convert_to_tensor(x, dtype=dtype, ...)  here, but that
#    1010   # allows some conversions that cast() can't do, e.g. casting numbers to
#    1011   # strings.
# -> 1012   x = ops.convert_to_tensor(x, name="x")
#    1013   if x.dtype.is_complex and base_type.is_floating:
#    1014     logging.warn(
#    1015         f"You are casting an input of type {x.dtype.name} to an "
#    1016         f"incompatible dtype {base_type.name}.  This will "
#    1017         "discard the imaginary part and may not be what you "
#    1018         "intended."
#    1019     )
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/tensorflow/python/profiler/trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/tensorflow/python/framework/ops.py:757, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#     755 # TODO(b/142518781): Fix all call-sites and remove redundant arg
#     756 preferred_dtype = preferred_dtype or dtype_hint
# --> 757 return tensor_conversion_registry.convert(
#     758     value, dtype, name, as_ref, preferred_dtype, accepted_result_types
#     759 )
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/tensorflow/python/framework/tensor_conversion_registry.py:209, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     207 overload = getattr(value, "__tf_tensor__", None)
#     208 if overload is not None:
# --> 209   return overload(dtype, name)  #  pylint: disable=not-callable
#     211 for base_type, conversion_func in get(type(value)):
#     212   # If dtype is None but preferred_dtype is not None, we try to
#     213   # cast to preferred_dtype first.
#     214   ret = None
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/keras/src/backend/tensorflow/core.py:84, in Variable.__tf_tensor__(self, dtype, name)
#      83 def __tf_tensor__(self, dtype=None, name=None):
# ---> 84     return tf.convert_to_tensor(self.value, dtype=dtype, name=name)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/tensorflow/python/util/dispatch.py:1264, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1262 # Fallback dispatch system (dispatch v1):
#    1263 try:
# -> 1264   return dispatch_target(*args, **kwargs)
#    1265 except (TypeError, ValueError):
#    1266   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1267   # TypeError, when given unexpected types.  So we need to catch both.
#    1268   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/tensorflow/python/framework/tensor_conversion.py:161, in convert_to_tensor_v2_with_dispatch(value, dtype, dtype_hint, name)
#      96 @tf_export.tf_export("convert_to_tensor", v1=[])
#      97 @dispatch.add_dispatch_support
#      98 def convert_to_tensor_v2_with_dispatch(
#      99     value, dtype=None, dtype_hint=None, name=None
#     100 ) -> tensor_lib.Tensor:
#     101   """Converts the given `value` to a `Tensor`.
#     102
#     103   This function converts Python objects of various types to `Tensor`
#    (...)    159     ValueError: If the `value` is a tensor not of given `dtype` in graph mode.
#     160   """
# --> 161   return convert_to_tensor_v2(
#     162       value, dtype=dtype, dtype_hint=dtype_hint, name=name
#     163   )
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/tensorflow/python/framework/tensor_conversion.py:171, in convert_to_tensor_v2(value, dtype, dtype_hint, name)
#     169 """Converts the given `value` to a `Tensor`."""
#     170 # preferred_dtype = preferred_dtype or dtype_hint
# --> 171 return tensor_conversion_registry.convert(
#     172     value, dtype, name, preferred_dtype=dtype_hint
#     173 )
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/tensorflow/python/framework/tensor_conversion_registry.py:234, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     225       raise RuntimeError(
#     226           _add_error_prefix(
#     227               f"Conversion function {conversion_func!r} for type "
#    (...)    230               f"actual = {ret.dtype.base_dtype.name}",
#     231               name=name))
#     233 if ret is None:
# --> 234   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     236 if ret is NotImplemented:
#     237   continue
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/tensorflow/python/ops/resource_variable_ops.py:2378, in _dense_var_to_tensor(var, dtype, name, as_ref)
#    2377 def _dense_var_to_tensor(var, dtype=None, name=None, as_ref=False):
# -> 2378   return var._dense_var_to_tensor(dtype=dtype, name=name, as_ref=as_ref)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/tensorflow/python/ops/resource_variable_ops.py:1624, in BaseResourceVariable._dense_var_to_tensor(***failed resolving arguments***)
#    1622   return self.read_value().op.inputs[0]
#    1623 else:
# -> 1624   return self.value()
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/tensorflow/python/ops/resource_variable_ops.py:657, in BaseResourceVariable.value(self)
#     655 if self._cached_value is not None:
#     656   return self._cached_value
# --> 657 with ops.colocate_with(None, ignore_existing=True):
#     658   return self._read_variable_op()
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/tensorflow/python/framework/ops.py:4544, in colocate_with(op, ignore_existing)
#    4543 def colocate_with(op, ignore_existing=False) -> ContextManager[None]:
# -> 4544   return _colocate_with_for_gradient(op, None, ignore_existing=ignore_existing)
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/site-packages/tensorflow/python/framework/ops.py:4498, in _colocate_with_for_gradient(op, gradient_uid, ignore_existing)
#    4486   """Wrapper for `Graph.container()` using the default graph.
#    4487
#    4488   Args:
#    (...)   4493     created stateful ops.
#    4494   """
#    4495   return get_default_graph().container(container_name)
# -> 4498 def _colocate_with_for_gradient(
#    4499     op, gradient_uid, ignore_existing=False,
#    4500 ) -> ContextManager[None]:
#    4501   """Returns a context manager for colocating op gradients with an op.
#    4502
#    4503   Internal API. In eager mode, returns a context manager that sets the default
#    (...)   4519     operation.
#    4520   """
#    4521   if context.executing_eagerly():
#
# KeyboardInterrupt:

# %%
# Plot the point history
utils.plot_history(total_point_history)

# %%
# Suppress warnings from imageio
import logging
logging.getLogger().setLevel(logging.ERROR)

# %%
filename = "./videos/lunar_lander.mp4"

utils.create_video(filename, env, q_network)
utils.embed_mp4(filename)
