# %%
# run first time
import sys
# !{sys.executable} -m pip install "gymnasium[box2d]"==1.2.3 stable_baselines3 tensorflow matplotlib numpy
# !{sys.executable} -m pip install "gymnasium[box2d]" imageio statsmodels pyvirtualdisplay tensorflow matplotlib numpy "imageio[ffmpeg]"
# Out:
# Requirement already satisfied: gymnasium==1.2.3 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from gymnasium[box2d]==1.2.3) (1.2.3)
# Requirement already satisfied: stable_baselines3 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (2.7.1)
# Requirement already satisfied: tensorflow in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (2.20.0)
# Requirement already satisfied: matplotlib in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (3.10.7)
# Requirement already satisfied: numpy in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (2.3.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from gymnasium==1.2.3->gymnasium[box2d]==1.2.3) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from gymnasium==1.2.3->gymnasium[box2d]==1.2.3) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from gymnasium==1.2.3->gymnasium[box2d]==1.2.3) (0.0.4)
# Requirement already satisfied: box2d==2.3.10 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from gymnasium[box2d]==1.2.3) (2.3.10)
# Requirement already satisfied: pygame>=2.1.3 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from gymnasium[box2d]==1.2.3) (2.1.3)
# Requirement already satisfied: swig==4.* in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from gymnasium[box2d]==1.2.3) (4.4.0)
# Requirement already satisfied: torch<3.0,>=2.3 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from stable_baselines3) (2.9.1)
# Requirement already satisfied: pandas in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from stable_baselines3) (2.3.3)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow) (6.33.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow) (3.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow) (1.74.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow) (3.12.0)
# Requirement already satisfied: h5py>=3.11.0 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from matplotlib) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from keras>=3.10.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from keras>=3.10.0->tensorflow) (0.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: markdown>=2.6.8 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorboard~=2.20.0->tensorflow) (3.10)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.4)
# Requirement already satisfied: filelock in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from torch<3.0,>=2.3->stable_baselines3) (3.20.3)
# Requirement already satisfied: sympy>=1.13.3 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from torch<3.0,>=2.3->stable_baselines3) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from torch<3.0,>=2.3->stable_baselines3) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from torch<3.0,>=2.3->stable_baselines3) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from torch<3.0,>=2.3->stable_baselines3) (2026.1.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pandas->stable_baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from pandas->stable_baselines3) (2025.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable_baselines3) (1.3.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/wangrunyuan/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: /Users/wangrunyuan/.pyenv/versions/3.11.9/bin/python -m pip install --upgrade pip

# %%
import time
from collections import deque, namedtuple

import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
import utils
import imageio
import PIL.Image
import matplotlib.pyplot as plt
from bidirection_lunar_lander import BidirectionalLunarLander

from stable_baselines3 import SAC
from stable_baselines3.common.vec_env import DummyVecEnv
import gymnasium as gym

VIDEO_NAME = "./env_recording.mp4"

# %%
########################## flap to inverted

# %%
def navie_inverted_controller(obs, phase, sign):
    x = obs[0]
    y = obs[1]
    vx = obs[2]
    vy = obs[3]
    theta = obs[4]
    omega = obs[5]

    # angle wrap to [-pi, pi]
    theta_wrapped = np.arctan2(np.sin(theta), np.cos(theta))
    theta_abs = abs(theta_wrapped)

    side = 0
    main = 0
    if phase == 1:
        if y > 1.4:
            return np.array([0, 0], dtype=np.float32), phase
            
        if theta_abs < 1.9:
            side = -0.6 * sign
            main = 0.8
        elif theta_abs > 1.9 and abs(omega) > 0.1 :
            side = 1 * sign
            main = -1
        else:
            phase = 2

    if phase == 2:
        if y > 1.4:
            return np.array([0, 0], dtype=np.float32), phase

        main = -0.6
        if vx > 0.1:
            side = 0.5
        elif vx < -0.1:
            side = -0.5
        else:
            side = 0

    return np.array([
        np.clip(main, -1.0, 1.0),
        np.clip(side, -1.0, 1.0)
    ], dtype=np.float32), phase

def getInitSign(vx0):
    if vx0 > 0:
        return 1
    else:
        return -1

# %%
class InvertedController:
    def __init__(self):
        self.phase = 0
        self.sign = 1

    def reset(self, vx0):
        self.phase = 1
        self.sign = getInitSign(vx0)

    def act(self, obs):
        action, phase = navie_inverted_controller(obs, self.phase, self.sign)
        self.phase = phase
        return action, phase

# %%
def env_proceed(reset, act, step=500, debug=False, create_video=None):
    render_mode="human"
    if create_video != None:
        render_mode="rgb_array"
    env = BidirectionalLunarLander(continuous=True, render_mode=render_mode)
    
    obs, info = env.reset()
    if create_video != None:
        create_video.append_data(env.render())
    reset(obs[2])
    
    for step in range(step):
        action = act(obs)
        obs, reward, terminated, truncated, info = env.step(action)

        if create_video != None:
            create_video.append_data(env.render())
        
        if debug:
            x = obs[0]
            vx = obs[2]
            theta = obs[4]
            omega = obs[5]
            theta_w = np.arctan2(np.sin(theta), np.cos(theta), )
            print(f"\raction: {action} x: {x}, vx: {vx} theta: {theta_w}, omega: {omega}")
        
        if terminated or truncated:
            if debug:
                print(f"Episode ended: {step}")
            break
    env.close

# %%
def create_video(reset, act, step=500, debug=False, fps=30):
    with imageio.get_writer(VIDEO_NAME, fps=fps, macro_block_size=1) as video:
        env_proceed(reset, act, step, debug, create_video=video)

# %%
##### See what happens by calling expert act in 500 steps
controller = InvertedController()

create_video(
# env_proceed(
    lambda vx0: controller.reset(vx0), 
    lambda obs: controller.act(obs)[0]
)

utils.embed_mp4(VIDEO_NAME)
# Out:
#     <video width="840" height="480" controls>
#     <source src="data:video/mp4;base64,..." type="video/mp4">
#     Your browser does not support the video tag.
#     </video>

# %%
########################## hover with inverted by RF learning

# %%
class InvertedHoverWrapper(gym.Wrapper):
    def __init__(self, env, controller, y_ref=1.2):
        super().__init__(env)
        self.controller = controller
        self.y_ref = y_ref

    def reset(self, **kwargs):
        obs, info = self.env.reset(**kwargs)
        self.controller.reset(obs[2])

        for _ in range(200):
            action, phase = self.controller.act(obs)
            obs, _, terminated, truncated, _ = self.env.step(action)

            if terminated or truncated:
                obs, info = self.env.reset(**kwargs)
                self.controller.reset(obs[2])

            if phase == 2:
                break

        return obs, info

    def step(self, action):
        obs, _, terminated, truncated, info = self.env.step(action)

        reward = self.tracking_reward(obs, action)

        done = terminated or truncated
        if abs(obs[1]) > 3.0:
            done = True

        return obs, reward, done, False, info

    def tracking_reward(self, obs, action):
        x, y, vx, vy, theta, omega, _, _ = obs
        main, side = action
    
        theta_err = np.arctan2(
            np.sin(theta - np.pi),
            np.cos(theta - np.pi)
        )
    
        reward = (
            - 4.0 * theta_err**2
            - 2.0 * omega**2
    
            - 3.0 * (y - self.y_ref)**2
            - 2.0 * vy**2
    
            - 3.0 * x**2
            - 2.0 * vx**2
    
            - 0.1 * main**2
            - 0.05 * side**2
        )
    
        return reward

# %%
def make_env(render=None):
    base_env = BidirectionalLunarLander(
        continuous=True,
        render_mode=render
    )
    controller = InvertedController()
    wrapped = InvertedHoverWrapper(base_env, controller)
    return wrapped

env = DummyVecEnv([make_env])

model = SAC(
    policy="MlpPolicy",
    env=env,
    learning_rate=3e-4,
    buffer_size=200_000,
    batch_size=256,
    gamma=0.99,
    tau=0.005,
    train_freq=1,
    gradient_steps=1,
    learning_starts=5_000,
    verbose=0
)

model.learn(total_timesteps=1000_000)
model.save("sac_inverted_hover")

# %%
class HybridExpert:
    def __init__(self, inverted_controller, rf_policy):
        self.inverted_controller = inverted_controller
        self.rf_policy = rf_policy
        self.phase = 0

    def reset(self, vx0):
        self.inverted_controller.reset(vx0)
        self.phase = 0

    def act(self, obs):
        if self.phase != 2:
            action, phase = self.inverted_controller.act(obs)
            self.phase = phase
            return action
        else:
            action, _ = self.rf_policy.predict(obs, deterministic=True)
            return action

# %%
##### Verify HybridExpert's capability in 500 steps
controller = InvertedController()
rf_policy = SAC.load("sac_inverted_hover")
hyperExpert = HybridExpert(controller, rf_policy)

create_video(
# env_proceed(
    lambda vx0: hyperExpert.reset(vx0), 
    lambda obs: hyperExpert.act(obs)
)

utils.embed_mp4(VIDEO_NAME)
# Out:
#     <video width="840" height="480" controls>
#     <source src="data:video/mp4;base64,..." type="video/mp4">
#     Your browser does not support the video tag.
#     </video>

# %%
########################## behavior cloning

# %%
def collect_one_episode(env, expert, max_steps=500):
    obs, info = env.reset()
    expert.reset(obs[2])
    
    episode = []
    for t in range(max_steps):
        action = expert.act(obs)

        episode.append({
            "obs": obs.copy(),
            "action": action.copy()
        })

        obs, reward, terminated, truncated, info = env.step(action)

        if terminated or truncated:
            break

    return episode

# %%
def collect_expert_episodes(
    env,
    expert,
    num_episodes=300,
    min_length=30,
    require_inverted=True
):
    expert_episodes = []

    for ep in range(num_episodes):
        episode = collect_one_episode(env, expert)

        if len(episode) < min_length:
            continue

        expert_episodes.append([
            {
                "obs": step["obs"],
                "action": step["action"]
            }
            for step in episode
        ])

        print(
            f"\rNum of episode {num_episodes} "
            f"Accepted episode {len(expert_episodes)} "
            f"(len={len(episode)})", end="", flush=True
        )

    print(f"\nCollected {len(expert_episodes)} expert episodes")
    return expert_episodes

# %%
def save_expert_episodes(expert_episodes, path="expert_lander.npz"):
    obs = []
    actions = []
    episode_lens = []

    for ep in expert_episodes:
        episode_lens.append(len(ep))
        for step in ep:
            obs.append(step["obs"])
            actions.append(step["action"])

    obs = np.array(obs, dtype=np.float32)
    actions = np.array(actions, dtype=np.float32)
    episode_lens = np.array(episode_lens, dtype=np.int32)

    np.savez(
        path,
        obs=obs,
        actions=actions,
        episode_lens=episode_lens
    )

    print(
        f"Saved {len(episode_lens)} episodes, "
        f"{len(obs)} total steps"
    )

# %%
env = BidirectionalLunarLander(continuous=True)
controller = InvertedController()
rf_policy = SAC.load("sac_inverted_hover")
hyperExpert = HybridExpert(controller, rf_policy)

expert_episodes = collect_expert_episodes(
    env,
    hyperExpert,
    num_episodes=35000,
    min_length=500
)

save_expert_episodes(expert_episodes, path="expert_lander.npz")
# Out:
# Num of episode 35000 Accepted episode 12640 (len=500)
# Collected 12640 expert episodes
# Saved 12640 episodes, 6320000 total steps

# %%
# Sanity check
data = np.load("expert_lander.npz")

obs_all = data["obs"]
actions_all = data["actions"]
episode_lens = data["episode_lens"]

env = BidirectionalLunarLander(continuous=True, render_mode="human")

ep_id = np.random.randint(len(episode_lens))
start = sum(episode_lens[:ep_id])
end = start + episode_lens[ep_id]

obs, _ = env.reset()
for t in range(start, end):
    obs, _, terminated, truncated, _ = env.step(actions_all[t])
    if terminated or truncated:
        break

# %%
def build_bc_policy(obs_dim=8, act_dim=2):
    inputs = layers.Input(shape=(obs_dim,))
    x = layers.Dense(128, activation="relu")(inputs)
    x = layers.Dense(128, activation="relu")(x)
    outputs = layers.Dense(act_dim, activation="tanh")(x)

    model = models.Model(inputs, outputs)
    return model

# %%
data = np.load("expert_lander.npz")

obs_all = data["obs"]          # (N, 8)
actions_all = data["actions"]  # (N, 2)

dataset = tf.data.Dataset.from_tensor_slices(
    (obs_all.astype(np.float32), actions_all.astype(np.float32))
)

dataset = dataset.shuffle(10000).batch(256).prefetch(tf.data.AUTOTUNE)

policy = build_bc_policy()

policy.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=3e-4),
    loss="mse"
)

policy.fit(
    dataset,
    epochs=30
)
# Out:
# Epoch 1/30
# 24688/24688 ━━━━━━━━━━━━━━━━━━━━ 11s 423us/step - loss: 0.0473
# Epoch 2/30
# 24688/24688 ━━━━━━━━━━━━━━━━━━━━ 10s 420us/step - loss: 0.0331
# Epoch 3/30
# 24688/24688 ━━━━━━━━━━━━━━━━━━━━ 11s 428us/step - loss: 0.0290
# Epoch 4/30
# 24688/24688 ━━━━━━━━━━━━━━━━━━━━ 10s 419us/step - loss: 0.0265
# Epoch 5/30
# 24688/24688 ━━━━━━━━━━━━━━━━━━━━ 10s 420us/step - loss: 0.0247
# Epoch 6/30
# 24688/24688 ━━━━━━━━━━━━━━━━━━━━ 10s 418us/step - loss: 0.0234
# Epoch 7/30
# 24688/24688 ━━━━━━━━━━━━━━━━━━━━ 10s 419us/step - loss: 0.0223
# Epoch 8/30
# 24688/24688 ━━━━━━━━━━━━━━━━━━━━ 10s 419us/step - loss: 0.0213
# Epoch 9/30
# 24688/24688 ━━━━━━━━━━━━━━━━━━━━ 10s 422us/step - loss: 0.0206
# Epoch 10/30
# 24688/24688 ━━━━━━━━━━━━━━━━━━━━ 10s 419us/step - loss: 0.0200
# Epoch 11/30
# 24688/24688 ━━━━━━━━━━━━━━━━━━━━ 10s 419us/step - loss: 0.0195
# Epoch 12/30
# 24688/24688 ━━━━━━━━━━━━━━━━━━━━ 10s 419us/step - loss: 0.0190
# Epoch 13/30
# 24688/24688 ━━━━━━━━━━━━━━━━━━━━ 10s 421us/step - loss: 0.0186
# Epoch 14/30
# 24688/24688 ━━━━━━━━━━━━━━━━━━━━ 10s 419us/step - loss: 0.0181
# Epoch 15/30
# 24688/24688 ━━━━━━━━━━━━━━━━━━━━ 10s 419us/step - loss: 0.0176
# Epoch 16/30
# 24688/24688 ━━━━━━━━━━━━━━━━━━━━ 10s 419us/step - loss: 0.0171
# Epoch 17/30
# 24688/24688 ━━━━━━━━━━━━━━━━━━━━ 10s 420us/step - loss: 0.0166
# Epoch 18/30
# 24688/24688 ━━━━━━━━━━━━━━━━━━━━ 10s 419us/step - loss: 0.0163
# Epoch 19/30
# 24688/24688 ━━━━━━━━━━━━━━━━━━━━ 10s 419us/step - loss: 0.0160
# Epoch 20/30
# 24688/24688 ━━━━━━━━━━━━━━━━━━━━ 10s 419us/step - loss: 0.0157
# Epoch 21/30
# 24688/24688 ━━━━━━━━━━━━━━━━━━━━ 10s 421us/step - loss: 0.0155
# Epoch 22/30
# 24688/24688 ━━━━━━━━━━━━━━━━━━━━ 10s 419us/step - loss: 0.0153
# Epoch 23/30
# 24688/24688 ━━━━━━━━━━━━━━━━━━━━ 10s 419us/step - loss: 0.0150
# Epoch 24/30
# 24688/24688 ━━━━━━━━━━━━━━━━━━━━ 10s 420us/step - loss: 0.0148
# Epoch 25/30
# 24688/24688 ━━━━━━━━━━━━━━━━━━━━ 10s 419us/step - loss: 0.0147
# Epoch 26/30
# 24688/24688 ━━━━━━━━━━━━━━━━━━━━ 10s 421us/step - loss: 0.0145
# Epoch 27/30
# 24688/24688 ━━━━━━━━━━━━━━━━━━━━ 10s 419us/step - loss: 0.0144
# Epoch 28/30
# 24688/24688 ━━━━━━━━━━━━━━━━━━━━ 10s 419us/step - loss: 0.0142
# Epoch 29/30
# 24688/24688 ━━━━━━━━━━━━━━━━━━━━ 10s 419us/step - loss: 0.0141
# Epoch 30/30
# 24688/24688 ━━━━━━━━━━━━━━━━━━━━ 10s 420us/step - loss: 0.0139

# %%
create_video(
# env_proceed(
    lambda _: None, 
    lambda obs: policy(obs.reshape(1, -1).astype(np.float32), training=False).numpy()[0]
)

utils.embed_mp4(VIDEO_NAME)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 create_video(
#       2 # env_proceed(
#       3     lambda _: None,
#       4     lambda obs: policy(obs.reshape(1, -1).astype(np.float32), training=False).numpy()[0]
#       5 )
#       7 utils.embed_mp4(VIDEO_NAME)
#
# Cell In[40], line 3, in create_video(reset, act, step, debug, fps)
#       1 def create_video(reset, act, step=500, debug=False, fps=30):
#       2     with imageio.get_writer(VIDEO_NAME, fps=fps, macro_block_size=1) as video:
# ----> 3         env_proceed(reset, act, step, debug, create_video=video)
#
# Cell In[21], line 13, in env_proceed(reset, act, step, debug, create_video)
#      10 reset(obs[2])
#      12 for step in range(step):
# ---> 13     action = act(obs)
#      14     obs, reward, terminated, truncated, info = env.step(action)
#      16     if create_video != None:
#
# Cell In[44], line 4, in <lambda>(obs)
#       1 create_video(
#       2 # env_proceed(
#       3     lambda _: None,
# ----> 4     lambda obs: policy(obs.reshape(1, -1).astype(np.float32), training=False).numpy()[0]
#       5 )
#       7 utils.embed_mp4(VIDEO_NAME)
#
# NameError: name 'policy' is not defined

# %%
########################## DAgger

# %%
def dagger_rollout(
    env,
    policy,
    expert,
    max_steps=500
):
    obs, _ = env.reset()
    expert.reset(obs[2])

    rollout_data = []

    for t in range(max_steps):
        # learner action
        obs_batch = obs.reshape(1, -1).astype(np.float32)
        learner_action = policy(obs_batch, training=False).numpy()[0]

        # expert label
        expert_action = expert.act(obs)

        rollout_data.append({
            "obs": obs.copy(),
            "action": expert_action.copy()
        })

        obs, _, terminated, truncated, _ = env.step(learner_action)

        if terminated or truncated:
            break

    return rollout_data

# %%
def aggregate_dataset(dataset, new_data):
    for step in new_data:
        dataset.append((
            step["obs"].astype(np.float32),
            step["action"].astype(np.float32)
        ))

# %%
def train_policy_tf(policy, dataset, epochs=5):
    obs = np.array([d[0] for d in dataset], dtype=np.float32)
    actions = np.array([d[1] for d in dataset], dtype=np.float32)

    ds = tf.data.Dataset.from_tensor_slices((obs, actions))
    ds = ds.shuffle(10000).batch(256).prefetch(tf.data.AUTOTUNE)

    policy.fit(ds, epochs=epochs, verbose=0)

# %%
dataset = list(zip(obs_all, actions_all))

env = BidirectionalLunarLander(continuous=True)
controller = InvertedController()
rf_policy = SAC.load("sac_inverted_hover")
hyperExpert = HybridExpert(controller, rf_policy)

for iteration in range(10):
    print(f"\nDAgger iteration {iteration}")

    rollout_data = dagger_rollout(
        env,
        policy,
        hyperExpert,
        max_steps=500
    )

    aggregate_dataset(dataset, rollout_data)

    train_policy_tf(
        policy,
        dataset,
        epochs=5
    )
# Out:
# DAgger iteration 0
#
# DAgger iteration 1
#
# DAgger iteration 2
#
# DAgger iteration 3
#
# DAgger iteration 4
#
# DAgger iteration 5
#
# DAgger iteration 6
#
# DAgger iteration 7
#
# DAgger iteration 8
#
# DAgger iteration 9

# %%
create_video(
# env_proceed(
    lambda _: None, 
    lambda obs: policy(obs.reshape(1, -1).astype(np.float32), training=False).numpy()[0]
)

utils.embed_mp4(VIDEO_NAME)

# %%
policy.save('dagger_policy.keras')

# %%
##########################

# %%
policy = models.load_model('dagger_policy.keras')

# %%
create_video(
# env_proceed(
    lambda _: None, 
    lambda obs: policy(obs.reshape(1, -1).astype(np.float32), training=False).numpy()[0]
)

utils.embed_mp4(VIDEO_NAME)
# Out:
#     <video width="840" height="480" controls>
#     <source src="data:video/mp4;base64,..." type="video/mp4">
#     Your browser does not support the video tag.
#     </video>
